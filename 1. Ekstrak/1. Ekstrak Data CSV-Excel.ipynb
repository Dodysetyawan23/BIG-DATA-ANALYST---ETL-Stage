# %% [markdown]
# # Ekstract Data

# %% [markdown]
# Dalam proses ETL, Extract (Ekstrak) adalah langkah pertama di mana **data diambil dari berbagai sumber** untuk dikumpulkan dalam satu tempat. Tahap ini melibatkan pengambilan data mentah yang tersebar di beberapa sumber, seperti
# - database
# - file
# - aplikasi, atau sistem lainnya
#
# agar dapat diproses lebih lanjut dalam tahap Transform dan Load.

# %% [markdown]
# ## 1.CSV, Excel

# %%
import pandas as pd

# %%
# Grab data csv
df_military_expenditure = pd.read_csv('Military Expenditure.csv')

# %%
# preview data
df_military_expenditure
# Out:
#                     Country Name Country Code
# 0                          Aruba          ABW  \
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                       Indicator Name     Indicator Code      1960      1961
# 0    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS       NaN       NaN  \
# 1    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS       NaN  1.537008
# 2    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS       NaN       NaN
# 3    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS       NaN       NaN
# ...

# %%
# Grab data excel
df_military_expenditure2 = pd.read_excel('MilitaryExpenditure2.xls')

# %%
# preview data
df_military_expenditure2
# Out:
#                     Country Name Country Code
# 0                          Aruba          ABW  \
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                       Indicator Name     Indicator Code      1960      1961
# 0    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS       NaN       NaN  \
# 1    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS       NaN  1.537008
# 2    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS       NaN       NaN
# 3    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS       NaN       NaN
# ...

# %% [markdown]
# # Reference
# - https://data.worldbank.org/indicator/MS.MIL.XPND.GD.ZS?locations=ID
